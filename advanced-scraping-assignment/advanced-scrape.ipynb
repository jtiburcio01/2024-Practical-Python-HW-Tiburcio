# %% [markdown]
# I used skills from week 1 of the advanced scraping module to scrape CUNY undergraduate demographic data from the New York State Education Department's website, which has a static url: https://data.nysed.gov/lists.php?start=67&type=higher

# %%
## import libraries
import pandas as pd
from random import randrange
from bs4 import BeautifulSoup
import time
import requests

# %%
#url to scrape
url = "https://data.nysed.gov/lists.php?start=67&type=higher"
## need to soup
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
## target each university on the page
uni_list = soup.find_all("div", class_="title")
uni_list
# Out:
# [<div class="title"><a href="profile.php?instid=800000052570">CANISIUS UNIVERSITY OF BUFFALO, NY </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000042817">CATHOLIC MED CTR BROOK/QUEENS SCH NR </a></div>,
#  <div class="title"><a href="profile.php?instid=800000065326">CAYUGA COMM COLLEGE - FULTON CENTER </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000054552">CAYUGA COUNTY COMM COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000050956">CAZENOVIA COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000040731">CENTRAL CITY BUSINESS INSTITUTE 665 </a></div>,
#  <div class="title"><a href="profile.php?instid=800000052979">CHRIST THE KING SEMINARY </a></div>,
#  <div class="title"><a href="profile.php?instid=800000065214">CHRISTIE'S EDUCATION, INC </a></div>,
#  <div class="title"><a href="profile.php?instid=800000090092">CITY SEMINARY OF NY GRADUATE CTR. </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000038743">CLARKSON UNIVERSITY </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000087726">CLARKSON UNIVERSITY CAPITAL REGION </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000053812">CLINTON COMMUNITY COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000034614">COCHRAN SCH NURSING ST JOHN RVRDL HO </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000068498">COLD SPRING HARBOR LABORATORY </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000050944">COLGATE UNIVERSITY </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000050301">COLGATE-ROCHESTER DIVINITY  SCHOOL </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000047853">COLL NEW ROCHELLE DIST COUN 31 CMPS </a></div>,
#  <div class="title"><a href="profile.php?instid=800000047063">COLL NEW ROCHELLE ROSA PARKS CAMPUS </a></div>,
#  <div class="title"><a href="profile.php?instid=800000047854">COLL OF NEW ROCHELLE AT NY THEO SEMI </a></div>,
#  <div class="title"><a href="profile.php?instid=800000045434">COLL OF NEW ROCHELLE BROOKLYN CAMPUS </a></div>,
#  <div class="title"><a href="profile.php?instid=800000047855">COLLEGE OF INSURANCE </a></div>,
#  <div class="title"><a href="profile.php?instid=800000035120">COLLEGE OF NEW ROCHELLE </a></div>,
#  <div class="title"><a href="profile.php?instid=800000066351">COLLEGE OF NEW ROCHELLE - COUNCIL 37 </a></div>,
#  <div class="title"><a href="profile.php?instid=800000090404">COLLEGE OF NEW ROCHELLE - ROSA PARKS </a></div>,
#  <div class="title"><a href="profile.php?instid=800000045844">COLLEGE OF NEW ROCHELLE CO-OP CITY </a></div>,
#  <div class="title"><a href="profile.php?instid=800000046589">COLLEGE OF NEW ROCHELLE JOHN CARDIN  </a></div>,
#  <div class="title"><a href="profile.php?instid=800000055585">COLLEGE OF SAINT ROSE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000047082">COLUMBIA UNIVERSITY </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000053700">COLUMBIA-GREENE COMMUNITY COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000035634">CONCORDIA COLLEGE </a></div>,
#  <div class="title"><a href="profile.php?instid=800000034375">CONNECTICUT COLLEGE </a></div>,
#  <div class="title"><a href="profile.php?instid=800000047356">COOPER UNION </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000036378">CORNELL UN INST RES DEV </a></div>,
#  <div class="title"><a href="profile.php?instid=800000047866">CORNELL UNIV MEDICAL CAMPUS </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000036397">CORNELL UNIVERSITY </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000084405">CORNELL UNIVERSITY-CORNELNYC TECH  </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000037963">CORNING COMM COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000040675">CROUSE HOSPITAL COLLEGE OF NURSING </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000053384">CULINARY INSTITUTE OF AMERICA 697 </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000047621">CUNY BERNARD M. BARUCH COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000043781">CUNY BROOKLYN COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000047619">CUNY CENTRAL ADMINISTRATION </a></div>,
#  <div class="title"><a href="profile.php?instid=800000047047">CUNY CITY COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000041831">CUNY COLLEGE OF STATEN ISLAND </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000047620">CUNY GRADUATE SCHOOL </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000047622">CUNY HUNTER COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000047317">CUNY JOHN JAY COL CRIM JUSTICE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000043091">CUNY LAW SCHOOL AT QUEENS  </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000046077">CUNY LEHMAN COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000045393">CUNY NYC COLLEGE OF TECHNOLOGY </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000043093">CUNY QUEENS COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000089728">CUNY SCHOOL OF PROFESSIONAL STUDIES </a></div>,
#  <div class="title"><a href="profile.php?instid=800000073513">CUNY STELLA AND CHARLES GUTTMAN COMM </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title"><a href="profile.php?instid=800000042570">CUNY YORK COLLEGE </a></div>,
#  <div class="title">HIGHER EDUCATION</div>,
#  <div class="title">HIGHER EDUCATION</div>]

# %%
## extract all a tags in the list of divs
atags = []
for div_element in uni_list:
    for atag in div_element.find_all("a"):
        atags.append(atag)
## extract just the CUNYs
cuny_atags = []
for atag in atags:
    if "CUNY" in atag.text:
        cuny_atags.append(atag)
cuny_atags
# Out:
# [<a href="profile.php?instid=800000047621">CUNY BERNARD M. BARUCH COLLEGE </a>,
#  <a href="profile.php?instid=800000043781">CUNY BROOKLYN COLLEGE </a>,
#  <a href="profile.php?instid=800000047619">CUNY CENTRAL ADMINISTRATION </a>,
#  <a href="profile.php?instid=800000047047">CUNY CITY COLLEGE </a>,
#  <a href="profile.php?instid=800000041831">CUNY COLLEGE OF STATEN ISLAND </a>,
#  <a href="profile.php?instid=800000047620">CUNY GRADUATE SCHOOL </a>,
#  <a href="profile.php?instid=800000047622">CUNY HUNTER COLLEGE </a>,
#  <a href="profile.php?instid=800000047317">CUNY JOHN JAY COL CRIM JUSTICE </a>,
#  <a href="profile.php?instid=800000043091">CUNY LAW SCHOOL AT QUEENS  </a>,
#  <a href="profile.php?instid=800000046077">CUNY LEHMAN COLLEGE </a>,
#  <a href="profile.php?instid=800000045393">CUNY NYC COLLEGE OF TECHNOLOGY </a>,
#  <a href="profile.php?instid=800000043093">CUNY QUEENS COLLEGE </a>,
#  <a href="profile.php?instid=800000089728">CUNY SCHOOL OF PROFESSIONAL STUDIES </a>,
#  <a href="profile.php?instid=800000073513">CUNY STELLA AND CHARLES GUTTMAN COMM </a>,
#  <a href="profile.php?instid=800000042570">CUNY YORK COLLEGE </a>]

# %%
## extract the hrefs
cuny_hrefs = []
for atag2 in cuny_atags:
    cuny_hrefs.append(atag2.get("href"))
    
cuny_hrefs
# Out:
# ['profile.php?instid=800000047621',
#  'profile.php?instid=800000043781',
#  'profile.php?instid=800000047619',
#  'profile.php?instid=800000047047',
#  'profile.php?instid=800000041831',
#  'profile.php?instid=800000047620',
#  'profile.php?instid=800000047622',
#  'profile.php?instid=800000047317',
#  'profile.php?instid=800000043091',
#  'profile.php?instid=800000046077',
#  'profile.php?instid=800000045393',
#  'profile.php?instid=800000043093',
#  'profile.php?instid=800000089728',
#  'profile.php?instid=800000073513',
#  'profile.php?instid=800000042570']

# %%
# extract the college names too
cuny_names = []
for tag in cuny_atags:
    cuny_name = tag.text.strip()
    cuny_names.append(cuny_name)

(cuny_names)
# Out:
# ['CUNY BERNARD M. BARUCH COLLEGE',
#  'CUNY BROOKLYN COLLEGE',
#  'CUNY CENTRAL ADMINISTRATION',
#  'CUNY CITY COLLEGE',
#  'CUNY COLLEGE OF STATEN ISLAND',
#  'CUNY GRADUATE SCHOOL',
#  'CUNY HUNTER COLLEGE',
#  'CUNY JOHN JAY COL CRIM JUSTICE',
#  'CUNY LAW SCHOOL AT QUEENS',
#  'CUNY LEHMAN COLLEGE',
#  'CUNY NYC COLLEGE OF TECHNOLOGY',
#  'CUNY QUEENS COLLEGE',
#  'CUNY SCHOOL OF PROFESSIONAL STUDIES',
#  'CUNY STELLA AND CHARLES GUTTMAN COMM',
#  'CUNY YORK COLLEGE']

# %%
## separate the institution id from the rest
cuny_ids = [href.split('=')[1] for href in cuny_hrefs]
cuny_ids
# Out:
# ['800000047621',
#  '800000043781',
#  '800000047619',
#  '800000047047',
#  '800000041831',
#  '800000047620',
#  '800000047622',
#  '800000047317',
#  '800000043091',
#  '800000046077',
#  '800000045393',
#  '800000043093',
#  '800000089728',
#  '800000073513',
#  '800000042570']

# %%
year = ["2022","2023","2024"]
base_url = "https://data.nysed.gov/highered-enrollment.php"
links = [f"{base_url}?year={y}&instid={cuny_id}"for y in year for cuny_id in cuny_ids]
links
# Out:
# ['https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047621',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043781',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047619',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047047',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000041831',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047620',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047622',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047317',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043091',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000046077',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000045393',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043093',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000089728',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000073513',
#  'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000042570',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047621',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043781',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047619',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047047',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000041831',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047620',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047622',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047317',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043091',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000046077',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000045393',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043093',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000089728',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000073513',
#  'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000042570',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047621',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043781',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047619',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047047',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000041831',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047620',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047622',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047317',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043091',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000046077',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000045393',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043093',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000089728',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000073513',
#  'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000042570']

# %%
year_ = {y: links for y in years}
year_dict
# Out:
# {'2022': ['https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047621',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043781',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047619',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047047',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000041831',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047620',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047622',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047317',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043091',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000046077',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000045393',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043093',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000089728',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000073513',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000042570',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047621',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043781',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047619',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047047',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000041831',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047620',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047622',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047317',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043091',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000046077',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000045393',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043093',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000089728',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000073513',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000042570',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047621',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043781',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047619',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047047',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000041831',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047620',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047622',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047317',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043091',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000046077',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000045393',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043093',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000089728',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000073513',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000042570'],
#  '2023': ['https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047621',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043781',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047619',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047047',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000041831',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047620',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047622',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047317',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043091',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000046077',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000045393',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043093',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000089728',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000073513',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000042570',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047621',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043781',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047619',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047047',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000041831',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047620',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047622',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047317',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043091',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000046077',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000045393',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043093',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000089728',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000073513',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000042570',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047621',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043781',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047619',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047047',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000041831',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047620',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047622',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047317',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043091',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000046077',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000045393',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043093',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000089728',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000073513',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000042570'],
#  '2024': ['https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047621',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043781',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047619',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047047',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000041831',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047620',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047622',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047317',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043091',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000046077',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000045393',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000043093',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000089728',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000073513',
#   'https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000042570',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047621',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043781',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047619',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047047',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000041831',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047620',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047622',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000047317',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043091',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000046077',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000045393',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000043093',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000089728',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000073513',
#   'https://data.nysed.gov/highered-enrollment.php?year=2023&instid=800000042570',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047621',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043781',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047619',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047047',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000041831',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047620',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047622',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000047317',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043091',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000046077',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000045393',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000043093',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000089728',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000073513',
#   'https://data.nysed.gov/highered-enrollment.php?year=2024&instid=800000042570']}

# %%
len(links)
# Out:
# 45

# %%
df_list = []
broken_links = []
total_links = len(links)

for counter, cuny_id in enumerate(cuny_ids, start=1):
    target_link = links[counter - 1]
    print(f"Scraping {counter} of {total_links}")
    try:
        data = pd.read_html(target_link)
        df = data[0]
        df["INSTID"] = cuny_id
        df["COLLEGE"] = cuny_names[counter - 1]
        df["YEAR"] = year_value 
        df_list.append(df)
    except Exception as e:
        print(f"{target_link}: {e}")
        broken_links.append(target_link)
    finally:
        snooze = randrange(5, 10)
        print(f"Snoozing for {snooze} seconds")
        time.sleep(snooze)

print(f"Done scraping all units")
# Out:
# Scraping 1 of 45
# Snoozing for 9 seconds
# Scraping 2 of 45
# Snoozing for 9 seconds
# Scraping 3 of 45
# https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000047619: No tables found
# Snoozing for 7 seconds
# Scraping 4 of 45
# Snoozing for 8 seconds
# Scraping 5 of 45
# Snoozing for 6 seconds
# Scraping 6 of 45
# Snoozing for 5 seconds
# Scraping 7 of 45
# Snoozing for 7 seconds
# Scraping 8 of 45
# Snoozing for 8 seconds
# Scraping 9 of 45
# Snoozing for 8 seconds
# Scraping 10 of 45
# Snoozing for 8 seconds
# Scraping 11 of 45
# Snoozing for 6 seconds
# Scraping 12 of 45
# Snoozing for 6 seconds
# Scraping 13 of 45
# https://data.nysed.gov/highered-enrollment.php?year=2022&instid=800000089728: No tables found
# Snoozing for 8 seconds
# Scraping 14 of 45
# Snoozing for 5 seconds
# Scraping 15 of 45
# Snoozing for 7 seconds
# Done scraping all units

# %%
final_df = pd.concat(df_list, ignore_index = True)
final_df = final_df.drop(columns=['Unnamed: 4'])
final_df = final_df[final_df['SUBGROUP'] != 'Total']
final_df = final_df[final_df['SUBGROUP'] != 'Gender']
final_df = final_df[final_df['SUBGROUP'] != 'Race and Ethnicity']

# %%
final_df
# Out:
#                                       SUBGROUP FULL-TIME PART-TIME  TOTAL  \
# 0                                 All Students     12455      3404  15859
# 1                   Degree/Certificate Seeking     12400      3083  15483
# 2                                   First-Time      2514        18   2532
# 3                                  Transfer-In      1132       366   1498
# 4                         Continuing/Returning      8754      2699  11453
# ..                                         ...       ...       ...    ...
# 268  Native Hawaiian or Other Pacific Islander        16         9     25
# 269                                      White       248       205    453
# 270                                Multiracial       148        48    196
# 271                 Unknown race and ethnicity         0         0      0
# 272                           U.S. Nonresident       157        64    221
#
#            INSTID                         COLLEGE  YEAR
# 0    800000047621  CUNY BERNARD M. BARUCH COLLEGE  None
# 1    800000047621  CUNY BERNARD M. BARUCH COLLEGE  None
# 2    800000047621  CUNY BERNARD M. BARUCH COLLEGE  None
# 3    800000047621  CUNY BERNARD M. BARUCH COLLEGE  None
# 4    800000047621  CUNY BERNARD M. BARUCH COLLEGE  None
# ..            ...                             ...   ...
# 268  800000042570               CUNY YORK COLLEGE  None
# 269  800000042570               CUNY YORK COLLEGE  None
# 270  800000042570               CUNY YORK COLLEGE  None
# 271  800000042570               CUNY YORK COLLEGE  None
# 272  800000042570               CUNY YORK COLLEGE  None
#
# [234 rows x 7 columns]
